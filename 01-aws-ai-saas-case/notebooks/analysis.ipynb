# %%
import pandas as pd
import numpy as np

# %%
import os
os.getcwd()
# Out:
# '/Users/tajiri/Projects/finops-dojo-lab/01-aws-ai-saas-case/notebooks'

# %%
ls
# Out:
# analysis.ipynb

# %%
df = pd.read_csv("/Users/tajiri/Projects/finops-dojo-lab/01-aws-ai-saas-case/data/billing.csv")
df.head()
# Out:
#    usage_date billing_period  account_id      account_name  business_unit  \
# 0  2025-10-01        2025-10        1001  legacy-core-prod  core-platform
# 1  2025-10-01        2025-10        1001  legacy-core-prod  core-platform
# 2  2025-10-01        2025-10        1001  legacy-core-prod  core-platform
# 3  2025-10-01        2025-10        1001  legacy-core-prod  core-platform
# 4  2025-10-01        2025-10        1001  legacy-core-prod  core-platform
#
#   environment     region   service_name           product_name  \
# 0         dev  us-east-1    AWS Fargate           ai-assistant
# 1        prod  us-east-1    AWS Fargate  workflow-intelligence
# 2     staging  us-east-1     AWS Lambda          reporting-api
# 3     staging  us-east-1  Amazon Athena           ai-assistant
# 4        prod  us-east-1  Amazon Athena          reporting-api
#
#                 team  ...    sla_tier  budget_amount forecast_baseline_cost  \
# 0  product-analytics  ...     premium        8471.59                8540.90
# 1     ml-engineering  ...    standard        7981.26                8362.60
# 2     ml-engineering  ...     premium        4808.59                5090.49
# 3           platform  ...  enterprise       10841.25               10439.09
# 4           platform  ...    standard        3634.19                3702.55
#
#    acquisition_phase       tag_owner  tag_environment            tag_product  \
# 0    pre-integration             NaN              dev           ai-assistant
# 1    pre-integration  ml-engineering             prod  workflow-intelligence
# 2    pre-integration  ml-engineering          staging          reporting-api
# 3    pre-integration        platform          staging           ai-assistant
# 4    pre-integration        platform             prod                    NaN
#
#   tag_cost_center  allocation_status  anomaly_flag
# 0   core-platform          allocated             0
# 1   core-platform          allocated             0
# 2   core-platform          allocated             0
# 3   core-platform          allocated             0
# 4   core-platform          allocated             0
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (5000, 27)

# %%
df.head()
df.columns.tolist()
df.dtypes
# Out:
# usage_date                   object
# billing_period               object
# account_id                    int64
# account_name                 object
# business_unit                object
# environment                  object
# region                       object
# service_name                 object
# product_name                 object
# team                         object
# cost_usd                    float64
# usage_quantity              float64
# usage_unit                   object
# monthly_revenue_proxy       float64
# active_customers              int64
# workflows_processed           int64
# enterprise_customer_flag      int64
# sla_tier                     object
# budget_amount               float64
# forecast_baseline_cost      float64
# acquisition_phase            object
# tag_owner                    object
# tag_environment              object
# tag_product                  object
# tag_cost_center              object
# allocation_status            object
# anomaly_flag                  int64
# dtype: object

# %%
df["usage_date"] = pd.to_datetime(df["usage_date"])
df["cost_usd"].describe()
# Out:
# count    5000.000000
# mean        0.967746
# std         1.512851
# min         0.000000
# 25%         0.100000
# 50%         0.350000
# 75%         1.160000
# max        11.360000
# Name: cost_usd, dtype: float64

# %%
df.groupby("service_name")["cost_usd"].sum().sort_values(ascending=False).head(10)
# Out:
# service_name
# AWS Fargate          1227.66
# Amazon EC2           1101.51
# Amazon RDS            950.59
# AWS Lambda            416.71
# NAT Gateway           286.48
# Amazon EBS            250.70
# Data Transfer         247.94
# Amazon S3             142.15
# Amazon CloudWatch     133.78
# AWS Glue               35.62
# Name: cost_usd, dtype: float64
